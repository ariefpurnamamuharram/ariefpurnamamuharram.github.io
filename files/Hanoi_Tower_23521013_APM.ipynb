# %% [markdown]
# <a href="https://colab.research.google.com/github/ariefpurnamamuharram/ariefpurnamamuharram.github.io/blob/master/files/Hanoi_Tower_23521013_APM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def TowerOfHanoi(n , source, destination, auxiliary):
  if n==1:
      print ("Pindahkan disk 1 dari",source,"ke",destination)
      return
  TowerOfHanoi(n-1, source, auxiliary, destination)
  print ("Pindahkan disk",n,"dari",source,"ke",destination)
  TowerOfHanoi(n-1, auxiliary, destination, source)
         

n = 3
TowerOfHanoi(n,'A','B','C')
# Out:
# Pindahkan disk 1 dari A ke B
# Pindahkan disk 2 dari A ke C
# Pindahkan disk 1 dari B ke C
# Pindahkan disk 3 dari A ke B
# Pindahkan disk 1 dari C ke A
# Pindahkan disk 2 dari C ke B
# Pindahkan disk 1 dari A ke B

# %%
try:
  a = int(input("Tell me one number:"))
  b = int(input("Tell me another number:"))
  print(a/b)
except:
  print("Bug in user input.")
# Out:
# Tell me one number:1
# Tell me another number:s
# Bug in user input.
