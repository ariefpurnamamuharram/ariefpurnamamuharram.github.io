# %% [markdown]
# <a href="https://colab.research.google.com/github/ariefpurnamamuharram/ariefpurnamamuharram.github.io/blob/master/ExampleNotebook_PCA_23521013_AriefPurnamaMuharram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install pandas
# !pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
print('NumPy version:', __import__('numpy').__version__)
print('Pandas version:', __import__('pandas').__version__)
print('Scikit-learn version:', __import__('sklearn').__version__)
# Out:
# NumPy version: 1.21.6
# Pandas version: 1.3.5
# Scikit-learn version: 1.0.2

# %%
from sklearn import datasets
from sklearn.decomposition import PCA


# Example using breast cancer
breast_cancer = datasets.load_breast_cancer()
X = breast_cancer.data
y = breast_cancer.target

# Example to reduce the dimension into 3.
pca = PCA(n_components=3)
X_r = pca.fit(X).transform(X)

X_r
# Out:
# array([[1160.1425737 , -293.91754364,   48.57839763],
#        [1269.12244319,   15.63018184,  -35.39453423],
#        [ 995.79388896,   39.15674324,   -1.70975298],
#        ...,
#        [ 314.50175618,   47.55352518,  -10.44240718],
#        [1124.85811531,   34.12922497,  -19.74208742],
#        [-771.52762188,  -88.64310636,   23.88903189]])
